# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics==8.0.58
# Out:
# ...
#   Using cached ultralytics-8.0.58-py3-none-any.whl (486 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8m-cls.pt")  # build a new model from scratch

# Use the model
data_path = r'/kaggle/input/emotion-detection-class'
model.train(data=data_path, epochs=200,patience=0, imgsz=640)
# Out:
# ...
# 100%|██████████| 32.7M/32.7M [00:00<00:00, 275MB/s]
# New https://pypi.org/project/ultralytics/8.0.231 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.58 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
model = YOLO('/kaggle/working/runs/classify/train5/weights/best.pt')

from PIL import Image
import cv2
import numpy as np
img = cv2.imread('/kaggle/input/emotion-detection-class/test/disgust/Z-1-_face_png_jpg.rf.80315f016eb39d31af4cffa8f909a12a.jpg')
results = model(img)
names_dict = results[0].names
probs = results[0].probs.tolist()
print (names_dict)
print (probs)
print(names_dict[np.argmax(probs)])
# Out:
# 0: 224x224 disgust 0.49, anger 0.22, sadness 0.12, fear 0.10, neutrality 0.07, 4.2ms
# Speed: 0.2ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# {0: 'anger', 1: 'disgust', 2: 'fear', 3: 'happiness', 4: 'neutrality', 5: 'sadness', 6: 'surprise'}
# [0.21876102685928345, 0.4888131320476532, 0.09795455634593964, 0.00020236569980625063, 0.07361552119255066, 0.12044311314821243, 0.0002103242150042206]
# disgust

# %%
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.10.12 torch-2.0.0 CPU
#
# PyTorch: starting from /kaggle/working/runs/classify/train5/weights/best.pt with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 7) (30.2 MB)
#
# ONNX: starting export with onnx 1.15.0...
# ONNX: export success ✅ 1.0s, saved as /kaggle/working/runs/classify/train5/weights/best.onnx (60.2 MB)
#
# Export complete (1.2s)
# Results saved to /kaggle/working/runs/classify/train5/weights
# Predict:         yolo predict task=classify model=/kaggle/working/runs/classify/train5/weights/best.onnx imgsz=224
# Validate:        yolo val task=classify model=/kaggle/working/runs/classify/train5/weights/best.onnx imgsz=224 data=/kaggle/input/emotion-detection-class
# Visualize:       https://netron.app
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ...
